# %%
import pandas as pd

# %%
## a dataset of lead samples between 2014 and 2023
df = pd.read_csv("Tap Test Lead Copper.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3943 entries, 0 to 3942
# Data columns (total 13 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   KIT ID Number                              3943 non-null   int64
#  1   Borough                                    3943 non-null   object
#  2   AVG % of limit in overlimit samples        3943 non-null   object
#  3   AVG lead levels in over-limit samples      3943 non-null   object
#  4   AVG lead level in zip                      3943 non-null   float64
#  5   # of samples over limit in zip             3943 non-null   int64
#  6   Count of samples                           3943 non-null   int64
#  7   Zipcode                                    3943 non-null   int64
#  8   Date Collected                             3943 non-null   object
#  9   Received Date                              3943 non-null   object
#  10  Percent over limit                         3943 non-null   object
#  11  First Draw at-the-tap Lead level (µg/l)    3943 non-null   int64
#  12  First Draw at-the-tap copper level (mg/l)  3943 non-null   float64
# dtypes: float64(2), int64(5), object(6)
# memory usage: 400.6+ KB

# %%
df.describe()
# Out:
#        KIT ID Number  AVG lead level in zip  # of samples over limit in zip  \
# count   3.943000e+03            3943.000000                     3943.000000
# mean    3.581230e+07               8.108293                        6.390566
# std     6.028639e+07              10.122107                        6.442040
# min     1.513650e+05               0.000000                        0.000000
# 25%     1.612976e+07               2.575668                        1.000000
# 50%     1.814986e+07               4.171053                        4.000000
# 75%     2.118002e+07               8.435294                       15.000000
# max     2.311009e+08              48.573529                       23.000000
#
#        Count of samples      Zipcode  First Draw at-the-tap Lead level (µg/l)  \
# count       3943.000000   3943.00000                              3943.000000
# mean         115.568095  10882.68704                                 8.108293
# std          106.402171    501.48005                               110.372370
# min            1.000000  10010.00000                                 0.000000
# 25%           31.000000  10309.00000                                 0.000000
# 50%           69.000000  11212.00000                                 2.000000
# 75%          217.000000  11358.00000                                 6.000000
# max          337.000000  11694.00000                              4960.000000
#
#        First Draw at-the-tap copper level (mg/l)
# count                                3943.000000
# mean                                    0.134403
# std                                     0.300461
# min                                     0.003000
# 25%                                     0.092000
# 50%                                     0.123000
# 75%                                     0.156000
# max                                    18.170000

# %%
## see statistics on lead levels across data set. average is below level, but STD suggests a high number of samples surpassing lead level regulation
df["First Draw at-the-tap Lead level (µg/l)"].describe()
# Out:
# count    3943.000000
# mean        8.108293
# std       110.372370
# min         0.000000
# 25%         0.000000
# 50%         2.000000
# 75%         6.000000
# max      4960.000000
# Name: First Draw at-the-tap Lead level (µg/l), dtype: float64

# %%
df["First Draw at-the-tap Lead level (µg/l)"].max()
# Out:
# 4960

# %%
df.sort_values (by = "First Draw at-the-tap Lead level (µg/l)", ascending = False)
# Out:
#       KIT ID Number        Borough AVG % of limit in overlimit samples  \
# 1728        1410085         QUEENS                             1141.2%
# 3152       16129759  STATEN ISLAND                             2578.2%
# 1867        1410028         QUEENS                             5444.4%
# 2307       19161107         QUEENS                             2300.0%
# 932        22190339  STATEN ISLAND                             2578.2%
# ...             ...            ...                                 ...
# 2468       18149550  Staten Island                              784.0%
# 2466       18149886  Staten Island                              743.8%
# 2465       18149634  Staten Island                              237.3%
# 2464       18149430  Staten Island                             2578.2%
# 3942      231100779  Staten Island                              250.8%
#
#      AVG lead levels in over-limit samples  AVG lead level in zip  \
# 1728                           262.4782609              48.573529
# 3152                           386.7333333              27.631336
# 1867                           163.3333333               8.435294
# 2307                                   115              16.621622
# 932                            386.7333333              27.631336
# ...                                    ...                    ...
# 2468                                  39.2               3.983333
# 2466                                 29.75               1.455026
# 2465                                  35.6               2.575668
# 2464                           386.7333333              27.631336
# 3942                                40.125               3.742063
#
#       # of samples over limit in zip  Count of samples  Zipcode  \
# 1728                              23               136    11358
# 3152                              15               217    10314
# 1867                               3                85    11432
# 2307                               5                37    11415
# 932                               15               217    10314
# ...                              ...               ...      ...
# 2468                               5                60    10305
# 2466                               4               189    10308
# 2465                              15               337    10309
# 2464                              15               217    10314
# 3942                              16               252    10312
#
#      Date Collected Received Date Percent over limit  \
# 1728        6/13/14       6/17/14          33066.70%
# 3152        6/20/16       6/22/16          31506.70%
# 1867        6/18/14       6/20/14           2813.30%
# 2307        8/20/19       8/22/19           2533.30%
# 932         6/13/22       6/15/22           2000.00%
# ...             ...           ...                ...
# 2468        8/17/18       8/20/18              0.00%
# 2466        8/22/18       8/23/18              0.00%
# 2465        8/26/18       8/29/18              0.00%
# 2464        8/30/18        9/5/18              0.00%
# 3942        9/27/23       10/4/23              0.00%
#
#       First Draw at-the-tap Lead level (µg/l)  \
# 1728                                     4960
# 3152                                     4726
# 1867                                      422
# 2307                                      380
# 932                                       300
# ...                                       ...
# 2468                                        0
# 2466                                        0
# 2465                                        0
# 2464                                        0
# 3942                                        0
#
#       First Draw at-the-tap copper level (mg/l)
# 1728                                      0.430
# 3152                                      0.363
# 1867                                      0.420
# 2307                                      0.180
# 932                                       0.176
# ...                                         ...
# 2468                                      0.041
# 2466                                      0.093
# 2465                                      0.086
# 2464                                      0.130
# 3942                                      0.100
#
# [3943 rows x 13 columns]

# %%
overlimitLead = df[df["First Draw at-the-tap Lead level (µg/l)"] >= 15]

# %%
## 266 samples of lead over the 15 ug/L limit
overlimitLead.describe()
# Out:
#        KIT ID Number  AVG lead level in zip  # of samples over limit in zip  \
# count   2.660000e+02             266.000000                      266.000000
# mean    3.728524e+07              13.318864                        8.548872
# std     6.274549e+07              13.387829                        6.984042
# min     1.513770e+05               0.755102                        0.000000
# 25%     1.612966e+07               4.013141                        3.000000
# 50%     1.870565e+07               8.511111                        5.000000
# 75%     2.118009e+07              13.464286                       15.000000
# max     2.311009e+08              48.573529                       23.000000
#
#        Count of samples       Zipcode  \
# count        266.000000    266.000000
# mean         101.639098  10935.052632
# std           97.205236    488.833094
# min            2.000000  10013.000000
# 25%           31.250000  10312.000000
# 50%           59.000000  11223.000000
# 75%          136.000000  11358.000000
# max          337.000000  11693.000000
#
#        First Draw at-the-tap Lead level (µg/l)  \
# count                               266.000000
# mean                                 79.872180
# std                                 418.946413
# min                                  15.000000
# 25%                                  18.000000
# 50%                                  24.000000
# 75%                                  46.000000
# max                                4960.000000
#
#        First Draw at-the-tap copper level (mg/l)
# count                                 266.000000
# mean                                    0.188068
# std                                     0.254567
# min                                     0.005000
# 25%                                     0.100250
# 50%                                     0.134000
# 75%                                     0.189000
# max                                     3.197000

# %%
## 14.8 percent of tap samples over lead limit
3943/266
# Out:
# 14.823308270676693

# %%
## 549,203 apartments may have lead based on this sample (HALF A MILLION!)
3_705_000 * .14823308270676693
# Out:
# 549203.5714285715

# %%
## the average lead limit in these samples was over 4 times higher than regulation
79.87-15
64.87/15
# Out:
# 4.324666666666667

# %%
overlimitCopper = df[df["First Draw at-the-tap copper level (mg/l)"] >= 1.3]

# %%
## 3 samples over copper limit
overlimitCopper.describe()
# Out:
#        KIT ID Number  AVG lead level in zip  # of samples over limit in zip  \
# count   3.000000e+00               3.000000                        3.000000
# mean    1.848720e+07              12.591479                        0.666667
# std     3.246887e+06              15.094586                        0.577350
# min     1.612928e+07               3.142857                        0.000000
# 25%     1.663554e+07               3.887218                        0.500000
# 50%     1.714179e+07               4.631579                        1.000000
# 75%     1.966616e+07              17.315789                        1.000000
# max     2.219053e+07              30.000000                        1.000000
#
#        Count of samples       Zipcode  \
# count          3.000000      3.000000
# mean           9.333333  10913.666667
# std            8.736895    780.000855
# min            2.000000  10013.000000
# 25%            4.500000  10688.000000
# 50%            7.000000  11363.000000
# 75%           13.000000  11364.000000
# max           19.000000  11365.000000
#
#        First Draw at-the-tap Lead level (µg/l)  \
# count                                 3.000000
# mean                                 26.000000
# std                                  26.210685
# min                                   4.000000
# 25%                                  11.500000
# 50%                                  19.000000
# 75%                                  37.000000
# max                                  55.000000
#
#        First Draw at-the-tap copper level (mg/l)
# count                                   3.000000
# mean                                    7.801333
# std                                     8.998241
# min                                     2.037000
# 25%                                     2.617000
# 50%                                     3.197000
# 75%                                    10.683500
# max                                    18.170000

# %%
## create new dataset just showing lead samples that are over-limit
overlimitLead.to_csv("Over-Limit Lead Samples At Tap.csv")

# %%
## create new dataset just showing copper samples that are over-limit
overlimitCopper.to_csv("Over-Limit Copper Samples At Tap.csv")

# %%
overlimitLead[["Date Collected"]]
# Out:
#      Date Collected
# 22           6/5/20
# 28           6/5/20
# 32           6/5/20
# 41           6/6/20
# 60           6/6/20
# ...             ...
# 3905         8/6/23
# 3911         8/9/23
# 3930        9/14/23
# 3932        9/16/23
# 3933        9/16/23
#
# [266 rows x 1 columns]

# %%
# Path to your Excel file
##file_path = "/Users/lizziewalsh/dataProjects/Water Bottle Pitch/DataAnalysis/Specific Contaminants/Tap_Lead Copper_Data_2 draws_20250425.xlsx"

# List all sheet names in the Excel file
##excel_file = pd.ExcelFile(file_path)
##print("Available sheets:", excel_file.sheet_names)

# %%
## 2021-2022 data set. analyze a similar tap sample data set that analyzes lead levels from two draws from a resident's tap. converted measurement level in excel from mg/L to standard ug/L
Twodrawsdf = pd.read_csv("TapLeadCop_2draws_converted.csv")

# %%
Twodrawsdf.describe()
# Out:
#              Kit ID       Zipcode  # of samples in zip  \
# count  3.520500e+04  35205.000000         35205.000000
# mean   3.885101e+07  10813.938816           395.764380
# std    6.206739e+07    572.248304           310.185091
# min    1.410052e+06  10000.000000             1.000000
# 25%    1.723964e+07  10035.000000           163.000000
# 50%    1.926256e+07  11209.000000           307.000000
# 75%    2.128571e+07  11231.000000           562.000000
# max    2.331106e+08  12345.000000          1448.000000
#
#        FUNCTION # of samples in zip  #of samples over limit in zip  \
# count                  35205.000000                   35205.000000
# mean                     395.764380                      10.445221
# std                      310.185091                       9.821283
# min                        1.000000                       0.000000
# 25%                      163.000000                       4.000000
# 50%                      307.000000                       8.000000
# 75%                      562.000000                      13.000000
# max                     1448.000000                      42.000000
#
#        FUNCTION Count of samples over limit in zip  \
# count                                 35205.000000
# mean                                     10.445221
# std                                       9.821283
# min                                       0.000000
# 25%                                       4.000000
# 50%                                       8.000000
# 75%                                      13.000000
# max                                      42.000000
#
#        Lead First Draw_Converted (ug/L)  Lead First_Draw (mg/L)  \
# count                      35205.000000            35184.000000
# mean                           5.930720                0.005934
# std                          177.868891                0.177922
# min                            0.000000                0.000000
# 25%                            0.000000                0.000000
# 50%                            0.000000                0.000000
# 75%                            1.000000                0.001000
# max                        17029.000000               17.029000
#
#        Lead 1-2 Min_Converted (ug/L)  Lead 1-2 Minute Flush (mg/L)  \
# count                   35205.000000                  35179.000000
# mean                        1.503054                      0.001504
# std                        21.160007                      0.021168
# min                         0.000000                      0.000000
# 25%                         0.000000                      0.000000
# 50%                         0.000000                      0.000000
# 75%                         0.000000                      0.000000
# max                      2420.000000                      2.420000
#
#        Copper First Draw (mg/L)  Copper 1-2 Minute Flush (mg/L)  Unnamed: 19  \
# count              35184.000000                    35179.000000          0.0
# mean                   0.163360                        0.064820          NaN
# std                    0.269442                        0.184416          NaN
# min                    0.000000                        0.000000          NaN
# 25%                    0.084000                        0.020000          NaN
# 50%                    0.137000                        0.036000          NaN
# 75%                    0.196000                        0.080000          NaN
# max                   27.739000                       24.925000          NaN
#
#        Unnamed: 20  Number of first draw lead samples over limit  \
# count          0.0                                           1.0
# mean           NaN                                         931.0
# std            NaN                                           NaN
# min            NaN                                         931.0
# 25%            NaN                                         931.0
# 50%            NaN                                         931.0
# 75%            NaN                                         931.0
# max            NaN                                         931.0
#
#        Number of second draw lead over limit  \
# count                                    1.0
# mean                                     3.0
# std                                      NaN
# min                                      3.0
# 25%                                      3.0
# 50%                                      3.0
# 75%                                      3.0
# max                                      3.0
#
#        Average lead level in over limit samples
# count                                  1.000000
# mean                                 187.847476
# std                                         NaN
# min                                  187.847476
# 25%                                  187.847476
# 50%                                  187.847476
# 75%                                  187.847476
# max                                  187.847476

# %%
Twodrawsdf["Lead First Draw_Converted (ug/L)"].describe()
# Out:
# count    35205.000000
# mean         5.930720
# std        177.868891
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max      17029.000000
# Name: Lead First Draw_Converted (ug/L), dtype: float64

# %%
Twodraws_overlimitlead = Twodrawsdf[Twodrawsdf["Lead First Draw_Converted (ug/L)"] >= 15]

# %%
Twodraws_overlimitlead.sample()
# Out:
#          Kit ID   Borough  Zipcode Date Received Date Collected  \
# 22379  18247431  BROOKLYN    11238        3/1/18        2/28/18
#
#        # of samples in zip  FUNCTION # of samples in zip  \
# 22379                  850                         850.0
#
#        #of samples over limit in zip  \
# 22379                             29
#
#        FUNCTION Count of samples over limit in zip  \
# 22379                                           29
#
#       AVG lead levels in over-limit samples  ... Lead First_Draw (mg/L)  \
# 22379                                    96  ...                  0.018
#
#       Lead 1-2 Min_Converted (ug/L) Lead 1-2 Minute Flush (mg/L)  \
# 22379                             0                          0.0
#
#        Copper First Draw (mg/L)  Copper 1-2 Minute Flush (mg/L)  Unnamed: 19  \
# 22379                     0.208                           0.019          NaN
#
#        Unnamed: 20  Number of first draw lead samples over limit  \
# 22379          NaN                                           NaN
#
#        Number of second draw lead over limit  \
# 22379                                    NaN
#
#        Average lead level in over limit samples
# 22379                                       NaN
#
# [1 rows x 24 columns]

# %%
## 985 of samples are above lead limit
Twodraws_overlimitlead.describe()
# Out:
#              Kit ID       Zipcode  # of samples in zip  \
# count  9.850000e+02    985.000000           985.000000
# mean   3.287027e+07  10950.976650           390.141117
# std    5.309413e+07    513.716868           310.408696
# min    1.410225e+06  10000.000000            12.000000
# 25%    1.723724e+07  10464.000000           162.000000
# 50%    1.926040e+07  11216.000000           304.000000
# 75%    2.128501e+07  11237.000000           554.000000
# max    2.331106e+08  11693.000000          1448.000000
#
#        FUNCTION # of samples in zip  #of samples over limit in zip  \
# count                    985.000000                     985.000000
# mean                     390.141117                      12.841624
# std                      310.408696                       9.974525
# min                       12.000000                       0.000000
# 25%                      162.000000                       6.000000
# 50%                      304.000000                       9.000000
# 75%                      554.000000                      20.000000
# max                     1448.000000                      42.000000
#
#        FUNCTION Count of samples over limit in zip  \
# count                                   985.000000
# mean                                     12.841624
# std                                       9.974525
# min                                       0.000000
# 25%                                       6.000000
# 50%                                       9.000000
# 75%                                      20.000000
# max                                      42.000000
#
#        Lead First Draw_Converted (ug/L)  Lead First_Draw (mg/L)  \
# count                        985.000000              985.000000
# mean                         178.371574                0.178372
# std                         1049.329552                1.049330
# min                           15.000000                0.015000
# 25%                           20.000000                0.020000
# 50%                           32.000000                0.032000
# 75%                           72.000000                0.072000
# max                        17029.000000               17.029000
#
#        Lead 1-2 Min_Converted (ug/L)  Lead 1-2 Minute Flush (mg/L)  \
# count                     985.000000                    982.000000
# mean                       19.669036                      0.019729
# std                       116.667506                      0.116841
# min                         0.000000                      0.000000
# 25%                         1.000000                      0.001000
# 50%                         4.000000                      0.004000
# 75%                        11.000000                      0.011000
# max                      2420.000000                      2.420000
#
#        Copper First Draw (mg/L)  Copper 1-2 Minute Flush (mg/L)  Unnamed: 19  \
# count                985.000000                      982.000000          0.0
# mean                   0.502016                        0.150077          NaN
# std                    1.344700                        0.898630          NaN
# min                    0.010000                        0.001000          NaN
# 25%                    0.134000                        0.021000          NaN
# 50%                    0.203000                        0.040000          NaN
# 75%                    0.348000                        0.106000          NaN
# max                   27.739000                       24.925000          NaN
#
#        Unnamed: 20  Number of first draw lead samples over limit  \
# count          0.0                                           0.0
# mean           NaN                                           NaN
# std            NaN                                           NaN
# min            NaN                                           NaN
# 25%            NaN                                           NaN
# 50%            NaN                                           NaN
# 75%            NaN                                           NaN
# max            NaN                                           NaN
#
#        Number of second draw lead over limit  \
# count                                    0.0
# mean                                     NaN
# std                                      NaN
# min                                      NaN
# 25%                                      NaN
# 50%                                      NaN
# 75%                                      NaN
# max                                      NaN
#
#        Average lead level in over limit samples
# count                                       0.0
# mean                                        NaN
# std                                         NaN
# min                                         NaN
# 25%                                         NaN
# 50%                                         NaN
# 75%                                         NaN
# max                                         NaN

# %%
## 2.8% of samples are above lead limit
985/35205
# Out:
# 0.02797898025848601

# %%
## 2.3 million NYC apartments.
## Based on 2014-2023 data, 555,000 NYC apartments could have lead.
## Based on larger set of data between 2021 and 2022, 111,000 could have lead
