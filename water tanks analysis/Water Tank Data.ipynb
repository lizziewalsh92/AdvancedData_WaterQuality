# %%
import pandas as pd

# %%
df = pd.read_csv("Self-Reported_Drinking_Water_Tank_Inspection_Results_20250408.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55707 entries, 0 to 55706
# Data columns (total 49 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   BIN                           55616 non-null  float64
#  1   BOROUGH                       55707 non-null  object
#  2   ZIP                           55629 non-null  float64
#  3   HOUSE_NUM                     55707 non-null  object
#  4   STREET_NAME                   55707 non-null  object
#  5   BLOCK                         55707 non-null  int64
#  6   LOT                           55707 non-null  int64
#  7   CONFIRMATION_NUM              55707 non-null  object
#  8   REPORTING_YEAR                55707 non-null  int64
#  9   TANK_NUM                      55707 non-null  int64
#  10  INSPECTION_BY_FIRM            55685 non-null  object
#  11  INSPECTION_PERFORMED          55707 non-null  object
# ...

# %%
df.query("SI_RESULT_BIOLOGICAL_GROWTH == 'A'")
# Out:
#              BIN    BOROUGH      ZIP HOUSE_NUM       STREET_NAME  BLOCK  LOT  \
# 390    1074157.0  MANHATTAN  10029.0      1220      Fifth Avenue   1609    1
# 593    1040884.0  MANHATTAN  10065.0       812      Fifth Avenue   1377    3
# 605    1046953.0  MANHATTAN  10128.0        47  East 88th Street   1500   20
# 1619   1051245.0  MANHATTAN  10028.0       120   East End Avenue   1582   23
# 1786   1001831.0  MANHATTAN  10013.0       125      worth street    168   32
# ...          ...        ...      ...       ...               ...    ...  ...
# 52025  1077512.0  MANHATTAN  10002.0       160    Madison Street    255    1
# 52464  1038770.0  MANHATTAN  10017.0       310  East 46th Street   1338    5
# 54722  1038645.0  MANHATTAN  10016.0       305  East 40th Street   1333    1
# 54869  3048341.0   BROOKLYN  11206.0       760          Broadway   1723    1
# 55628  1040543.0  MANHATTAN  10022.0         4      Sutton Place   1369   24
#
# ...

# %%
## 237 tanks have unacceptable internal or external structure
df.query("(GI_RESULT_INTERNAL_STRUCTURE=='A') or (GI_RESULT_EXTERNAL_STRUCTURE=='A')")
# Out:
#              BIN    BOROUGH      ZIP HOUSE_NUM             STREET_NAME  BLOCK  \
# 96     1088469.0  MANHATTAN  10007.0       One  One World Trade Center     58
# 188    1077418.0  MANHATTAN  10038.0        15       Saint james Place    111
# 222    1038645.0  MANHATTAN  10016.0       305        East 40th Street   1333
# 439    1079000.0  MANHATTAN  10013.0       100           Centre street    167
# 1161   1077512.0  MANHATTAN  10002.0       160          Madison Street    255
# ...          ...        ...      ...       ...                     ...    ...
# 55085  3392969.0   BROOKLYN  11201.0       345            Adams street    140
# 55117  1053899.0  MANHATTAN  10037.0       506            Lenox Avenue   1733
# 55122  3392969.0   BROOKLYN  11201.0       345            adams street    140
# 55219  3325168.0   BROOKLYN  11233.0       311          Patchen Avenue   1688
# 55359  3002558.0   BROOKLYN  11201.0       210        Joralemon street    266
#
# ...

# %%
standards = df["MEET_STANDARDS"]

# %%
standards.describe()
# Out:
# count     11127
# unique        2
# top           Y
# freq      11116
# Name: MEET_STANDARDS, dtype: object

# %%
bacteriadf = df.query("(COLIFORM=='P') or (ECOLI=='P')")

# %%
## 213 water tanks have insect debris
df.query("SI_RESULT_DEBRIS_INSECTS=='A'")
# Out:
#              BIN    BOROUGH      ZIP HOUSE_NUM            STREET_NAME  BLOCK  \
# 593    1040884.0  MANHATTAN  10065.0       812           Fifth Avenue   1377
# 706    1086515.0  MANHATTAN  10016.0       462           First Avenue    962
# 820    3251647.0   BROOKLYN  11205.0       100  North Portland Avenue   2039
# 1550   1001241.0  MANHATTAN  10007.0       225               Broadway     88
# 1604   2013245.0      BRONX  10460.0      1010      East 178th Street   3130
# ...          ...        ...      ...       ...                    ...    ...
# 54010  1079000.0  MANHATTAN  10013.0       100          Centre Street    167
# 54285  1079000.0  MANHATTAN  10013.0       100          Centre Street    167
# 54620  4437132.0     QUEENS  11373.0     79-01               Broadway   1500
# 55431  1081771.0  MANHATTAN  10023.0     40-50       Amsterdam Avenue   1154
# 55614  3396962.0   BROOKLYN  11201.0       138      Willoughby Street    149
#
# ...

# %%
## 226 water tanks have rodent,bird, or insect debris
df.query("(SI_RESULT_RODENT_BIRD=='A') or (SI_RESULT_DEBRIS_INSECTS=='A')")
# Out:
#              BIN    BOROUGH      ZIP HOUSE_NUM            STREET_NAME  BLOCK  \
# 593    1040884.0  MANHATTAN  10065.0       812           Fifth Avenue   1377
# 706    1086515.0  MANHATTAN  10016.0       462           First Avenue    962
# 820    3251647.0   BROOKLYN  11205.0       100  North Portland Avenue   2039
# 1550   1001241.0  MANHATTAN  10007.0       225               Broadway     88
# 1604   2013245.0      BRONX  10460.0      1010      East 178th Street   3130
# ...          ...        ...      ...       ...                    ...    ...
# 54010  1079000.0  MANHATTAN  10013.0       100          Centre Street    167
# 54285  1079000.0  MANHATTAN  10013.0       100          Centre Street    167
# 54620  4437132.0     QUEENS  11373.0     79-01               Broadway   1500
# 55431  1081771.0  MANHATTAN  10023.0     40-50       Amsterdam Avenue   1154
# 55614  3396962.0   BROOKLYN  11201.0       138      Willoughby Street    149
#
# ...

# %%
df[(df["INSPECTION_DATE"] >= "2020-01-01") & (df["INSPECTION_DATE"] <= "2025-04-08")]
# Out:
# Empty DataFrame
# Columns: [BIN, BOROUGH, ZIP, HOUSE_NUM, STREET_NAME, BLOCK, LOT, CONFIRMATION_NUM, REPORTING_YEAR, TANK_NUM, INSPECTION_BY_FIRM, INSPECTION_PERFORMED, INSPECTION_DATE, GI_REQ_INTERNAL_STRUCTURE, GI_RESULT_INTERNAL_STRUCTURE, GI_REQ_EXTERNAL_STRUCTURE, GI_RESULT_EXTERNAL_STRUCTURE, GI_REQ_OVERFLOW_PIPES, GI_RESULT_OVERFLOW_PIPES, GI_REQ_ACCESS_LADDERS, GI_RESULT_ACCESS_LADDERS, GI_REQ_AIR_VENTS, GI_RESULT_AIR_VENTS, GI_REQ_ROOF_ACCESS, GI_RESULT_ROOF_ACCESS, SI_REQ_SEDIMENT, SI_RESULT_SEDIMENT, SI_REQ_BIOLOGICAL_GROWTH, SI_RESULT_BIOLOGICAL_GROWTH, SI_REQ_DEBRIS_INSECTS, SI_RESULT_DEBRIS_INSECTS, SI_REQ_RODENT_BIRD, SI_RESULT_RODENT_BIRD, SAMPLE_COLLECTED, LAB_NAME, NYS_CERTIFIED, ANALYTES, COLIFORM, ECOLI, MEET_STANDARDS, DELETED, LATITUDE, LONGITUDE, COMMUNITY_BOARD, COUNCIL_DISTRICT, CENSUS_TRACT, BBL, NTA, BATCH_DATE]
# Index: []
#
# [0 rows x 49 columns]

# %%
## 42 tanks have rodent or bird poop
df.query("SI_RESULT_RODENT_BIRD=='A'")
# Out:
#              BIN    BOROUGH      ZIP HOUSE_NUM                  STREET_NAME  \
# 593    1040884.0  MANHATTAN  10065.0       812                 Fifth Avenue
# 5113   3323300.0   BROOKLYN  11217.0       198                  Bond Street
# 7485   1034324.0  MANHATTAN  10036.0        33             West 46th street
# 7521   2101266.0      BRONX  10456.0      1118              Grand Concourse
# 7648   1048136.0  MANHATTAN  10128.0      1111                     park ave
# 9675   1041332.0  MANHATTAN  10021.0       720                  Park Avenue
# 11078  3002558.0   BROOKLYN  11201.0       210             Joralemon Street
# 11368  1048136.0  MANHATTAN  10128.0      1111                     park ave
# 13783  1084520.0  MANHATTAN  10039.0      2971  Frederick Douglas Boulevard
# 14679  1084673.0  MANHATTAN  10019.0        15             West 56th Street
# 15944  3002558.0   BROOKLYN  11201.0       210             Joralemon Street
# ...

# %%
bacteriadf["ZIP"].unique()
# Out:
# array([11238., 10307., 10013., 11201., 10461., 11106., 11101., 11217.,
#        10023., 10031.])

# %%
bacteriadf.count()
# Out:
# BIN                             25
# BOROUGH                         25
# ZIP                             25
# HOUSE_NUM                       25
# STREET_NAME                     25
# BLOCK                           25
# LOT                             25
# CONFIRMATION_NUM                25
# REPORTING_YEAR                  25
# TANK_NUM                        25
# INSPECTION_BY_FIRM              25
# INSPECTION_PERFORMED            25
# INSPECTION_DATE                 25
# GI_REQ_INTERNAL_STRUCTURE       25
# GI_RESULT_INTERNAL_STRUCTURE    23
# GI_REQ_EXTERNAL_STRUCTURE       25
# GI_RESULT_EXTERNAL_STRUCTURE    22
# GI_REQ_OVERFLOW_PIPES           25
# GI_RESULT_OVERFLOW_PIPES        22
# GI_REQ_ACCESS_LADDERS           25
# GI_RESULT_ACCESS_LADDERS        21
# GI_REQ_AIR_VENTS                25
# GI_RESULT_AIR_VENTS             23
# GI_REQ_ROOF_ACCESS              25
# GI_RESULT_ROOF_ACCESS           23
# SI_REQ_SEDIMENT                 25
# SI_RESULT_SEDIMENT              22
# ...

# %%
dnmeet = df.query("MEET_STANDARDS == 'N'")

# %%
dnmeet.count()
# Out:
# BIN                             11
# BOROUGH                         11
# ZIP                             11
# HOUSE_NUM                       11
# STREET_NAME                     11
# BLOCK                           11
# LOT                             11
# CONFIRMATION_NUM                11
# REPORTING_YEAR                  11
# TANK_NUM                        11
# INSPECTION_BY_FIRM              11
# INSPECTION_PERFORMED            11
# INSPECTION_DATE                 11
# GI_REQ_INTERNAL_STRUCTURE       11
# GI_RESULT_INTERNAL_STRUCTURE     7
# GI_REQ_EXTERNAL_STRUCTURE       11
# GI_RESULT_EXTERNAL_STRUCTURE     6
# GI_REQ_OVERFLOW_PIPES           11
# GI_RESULT_OVERFLOW_PIPES         8
# GI_REQ_ACCESS_LADDERS           11
# GI_RESULT_ACCESS_LADDERS         7
# GI_REQ_AIR_VENTS                11
# GI_RESULT_AIR_VENTS             10
# GI_REQ_ROOF_ACCESS              11
# GI_RESULT_ROOF_ACCESS            7
# SI_REQ_SEDIMENT                 11
# SI_RESULT_SEDIMENT               9
# ...

# %%
df.count()
# Out:
# BIN                             55616
# BOROUGH                         55707
# ZIP                             55629
# HOUSE_NUM                       55707
# STREET_NAME                     55707
# BLOCK                           55707
# LOT                             55707
# CONFIRMATION_NUM                55707
# REPORTING_YEAR                  55707
# TANK_NUM                        55707
# INSPECTION_BY_FIRM              55685
# INSPECTION_PERFORMED            55707
# INSPECTION_DATE                 55685
# GI_REQ_INTERNAL_STRUCTURE       55707
# GI_RESULT_INTERNAL_STRUCTURE    55610
# GI_REQ_EXTERNAL_STRUCTURE       55707
# GI_RESULT_EXTERNAL_STRUCTURE    55649
# GI_REQ_OVERFLOW_PIPES           55707
# GI_RESULT_OVERFLOW_PIPES        55648
# GI_REQ_ACCESS_LADDERS           55707
# GI_RESULT_ACCESS_LADDERS        55598
# GI_REQ_AIR_VENTS                55707
# GI_RESULT_AIR_VENTS             55653
# GI_REQ_ROOF_ACCESS              55707
# GI_RESULT_ROOF_ACCESS           55578
# ...

# %%
df["INSPECTION_DATE"] = pd.to_datetime(df["INSPECTION_DATE"], format="%m/%d/%Y")

# %%
start_date = pd.Timestamp("2020-01-01")
end_date = pd.Timestamp("2025-04-08")

# %%
df20tonow = df[(df["INSPECTION_DATE"] >= start_date) & (df["INSPECTION_DATE"] <= end_date)]

# %%
df20tonow.to_csv("Tank Inspection 2020-Present.csv", index=False)

# %%
dirtytanks = df20tonow.query("(SI_RESULT_RODENT_BIRD=='A') or (SI_RESULT_DEBRIS_INSECTS=='A') or (COLIFORM=='P') or (ECOLI=='P') or (GI_RESULT_INTERNAL_STRUCTURE =='A') or (SI_RESULT_BIOLOGICAL_GROWTH == 'A') or (GI_RESULT_EXTERNAL_STRUCTURE=='A')" )

# %%
dirtytanks.to_csv("Dirty Tanks 2020-Present.csv", index=False)
